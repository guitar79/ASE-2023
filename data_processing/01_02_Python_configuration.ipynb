# %% [markdown]
# # Python 사용 환경 구성
#
# 파이썬은 최근들어 인공 지능, 데이터 사이언스 등의 분야에서 널리 사용되고 있는 언어로 1991년에 발표되었습니다. 파이썬은 실무에서 많이 사용되었던 파이썬 2 버전(v2.7)과 새로운 기능을 계속 업그레이드하고 있는 파이썬 3 버전 (v3.X)이 있는데, 이 두 버전 간의 호환성 문제가 있습니다. 파이썬 2 버전(v2.7)은 현재 더이상 지원되지 않으므로 이 책에서는 파이썬 3 버전을 기준으로 설명합니다. 버전마다 for문 등의 루프에서 연산 효율이 매우 빨라지는 등 많은 개선이 되므로 최신 버전이 3개월이상 지나 안정화가 된 후에는 귀찮더라도 버전을 반드시 업데이트 하기를 추천합니다.
#
# 파이썬은 다음과 같은 특징이 있습니다.
#
# * 인터프리터 언어로 컴파일을 하지 않고 바로 실행할 수 있습니다.
# * 무료이며 직관적이고 쉽게 배울수 있어 사용자 층이 많이 늘어나고 있습니다.
# * 객체 지향 언어로 객체에 대한 속성을 바꾸는 방법을 사용합니다. (vs 절차 지향 언어)
# * 과학, 수학 관련 모듈들이 많은 사람들에 의해 개발되어 배포되고 있습니다.
# * 버전 업데이트가 빠르게 이루어지고 버전간 호환성 문제가 발생할 수 있습니다.
# * 실행 속도가 느린 편입니다. (개선할 수 있는 방법은 있음)

# %%
## 설치하기

# %% [markdown]
# ### 파이썬(Python) 설치
#
# [파이썬](https://www.python.org/downloads/) 공식 홈페이지에서 제공하는 설치 파일을 다운받아 이용할 수 있습니다. 윈도우, macOS, linux 등 자신의 OS에 맞는  파일을 다운받아 설치하여 사용할 수 있습니다. 하지만 이 방법의 경우 초보자들에게는 모듈 설치나 환경 구성이 어려올 수 있어서 추천하지 않습니다.
#
# 보통은 모듈설치나 가상환경 구성이 편리한 Anaconda, Canopy 등 다른 소프트웨어를 추가로 사용하는 경우가 많습니다.

# %% [markdown]
# ```{figure} ./images/python_web.png
# :name: python_web
#
# 파이썬 홈페이지 화면
# ```

# %% [markdown]
# ![python_web.png](data:image/png;base64,...)

# %% [markdown]
# ###  아나콘다 설치
#
# 파이썬을 계속 이용할 계획이 있으면 [아나콘다(Anaconda) 설치](https://anaconda.org/download/)를 권합니다. 윈도우, macOS, linux 등 자신의 OS에 맞는 아나콘다를 설치하면 여러가지 환경 변수들도 설정해 주어 사용이 편리합니다.
#
# 파이썬의 다양한 모듈이 있습니다.는 점은 장점이기도 하지만 여러가지 프로젝트를 실행하다 보면 버전 간의 충돌로 인해 단점이 되기도 합니다. 이때 필요한 것이 가상환경인데 아나콘다를 이용하면 모듈 설치와 가상환경 구성을 매우 쉽게 이용할 수 있습니다.

# %% [markdown]
# ```{figure} ./images/python_web.png
# :name: python_web
#
# 파이썬 홈페이지 화면
# ```

# %% [markdown]
# ![c0-anaconda.png](data:image/png;base64,...)

# %% [markdown]
# ## 파이썬 사용 환경
#
# 파이썬을 코딩하는 다양한 방법이 있습니다. 코딩을 하다보면 여러 에러가 발생할 수 있고, 이를 해결하는 과정을 쉽게 할 수 있는 방법이 필요하다. 코딩에 익숙한 전문가들은 텍스트 에디터 만으로 코딩하기도 하는데, 이를 날코딩 이라고 합니다.
#
# 통합 개발 환경(Integrated Development Environment, IDE)은 소프트웨어 개발에 관련된 모든 작업을 할 수 있는 툴을 말합니다. 기본적으로 텍스트 에디터를 기본으로 패키지 인클루딩, 컴파일, 디버그, 원격 서버 액세스, 바이너리 배포 등의 기능을 하나의 프로그램 안에서 모두 처리할 수 있도록 구성됩니다.

# %% [markdown]
# ### 주피터 노트북
#
# 주피터 노트북(Jupyter notebook)은 IPython 쉘을 이용해서 Python 코드가 포함된 동적인 문서를 작성하는 웹어플리케이션입니다. 실행 이후에는 기존 노트를 편집하거나 새로운 노트를 생성하고 편집할 수 있습니다. Jupyter notebook은 ipynb라는 확장자를 가지고 있습니다. 구글 코랩은 Jupyter notebook을 온라인으로 구현해 놓은 것이라고 생각할 수 있습니다. 다음 화면은 주피터 노트북을 실행한 것입니다.

# %% [markdown]
# ![Jupyter_notebook_web.png](data:image/png;base64,...)

# %% [markdown]
# #### 주피터 노트북 시작하기
#
# 주피터 노트북을 시작하는 방법은 아래와 같습니다.
#
#  * 시작 메뉴에서 아이콘을 통해 시작하는 방법
#  * Anaconda prompt에서 jupyter notebook 입력하는 방법

# %% [markdown]
# ![Jupyter_notebook.png](data:image/png;base64,...)

# %% [markdown]
# ![prompt_Jupyter_notebook.png](data:image/png;base64,...)

# %% [markdown]
# ### 셀
#
# 파이썬에서 코드나 텍스트를 입력할 수 있는 요소를 셀이라고 합니다. 구글 코랩에서도 텍스트 셀과 코드 셀을 사용할 수 있으며, 각 셀을 클릭하여 쉽게 수정할 수 있습니다. 또한 셀 추가, 삭제, 위치 이동이 매우 쉬우며 텍스트 셀 / 코드 셀을 상호 변환할 수도 있습니다. ([참고](https://blog.naver.com/PostView.naver?blogId=nabilera1&logNo=222587254561&parentCategoryNo=&categoryNo=112&viewDate=&isShowPopularPosts=true&from=search))
#
# ```{admonition} 단축키
# * Ctrl + mm : 현재 셀 마크다운 셀로 변환
# * Ctrl + ma : 현재 셀 코드 셀로 변환
# ```
#
# 코드 셀은 런타임과 연결하여 파이썬 코드를 실행할 수 있는 셀입니다. 구글 코랩은 사용자들에게 무료 클라우드 GPU 서비스를 제공합니다. 약 300만원에 달하는 테슬라 GPU를 제공해 우수한 성능으로 코드를 확인할 수 있습니다. 특히 성능이 중요시되는 인공지능 모델을 만들때나 많은 양의 데이터를 분석할 때 코랩을 사용하면 빠른 시간 내에 코드 결과를 확인할 수 있습니다.
#
# 구글 코랩을 사용할 때 드라이브 런타임 최대 수명이 12시간인 가상머신에 연결되는 것이며 일정 시간이 지나면 자동으로 런타임이 끊겨 코드의 실행 결과 등이 초기화됩니다. 코랩에서 컴퓨팅 리소스를 무료로 제공하기 위해 사용되는 방식입니다. 하지만 무조건 12시간이 아니라 최대 12시간 연결을 보장하려 노력하고 입력이 없다면 실제로는 빠른 시간내에 연결이 끊기게 됩니다.

# %%
# This is code cell
a = 1
print(a)

# %% [markdown]
# #### 텍스트 셀
#
# 텍스트 셀은 Markdown 문법을 사용하며 텍스트 파일로 확장자로는 .md를 주로 사용한다. 텍스트 기반의 마크업 언어로 2004년 존그루버에 의해 만들어졌으며 쉽게 쓰고 읽을 수 있으며 HTML로 변환이 가능합니다. 특수기호와 문자를 이용한 매우 간단한 구조의 문법을 사용하여 웹에서도 보다 빠르게 컨텐츠를 작성하고 보다 직관적으로 인식할 수 있습니다. 자세한 내용은 [Markdown 작성법](https://gist.github.com/ihoneymon/652be052a0727ad59601)을 참고하기 바랍니다.
#
# 마크다운이 최근 각광받기 시작한 이유는 깃헙(https://github.com) 덕분입니다. 깃헙의 저장소Repository에 관한 정보를 기록하는 README.md는 깃헙을 사용하는 사람이라면 누구나 가장 먼저 접하게 되는 것이 마크다운 문서였습니다. 마크다운을 통해서 설치방법, 소스코드 설명, 이슈 등을 간단하게 기록하고 가독성을 높일 수 있다는 강점이 부각되면서 점점 여러 곳으로 퍼져가게 되었습니다.
#
# ** Markdown 문법의 장점 **
#
# ```{admonition} 장점
# 1. 간결합니다.
# 2. 별도의 도구없이 작성가능합니다.
# 3. 다양한 형태로 변환이 가능합니다.
# 4. 텍스트(Text)로 저장되기 때문에 용량이 적어 보관이 용이합니다.
# 5. 텍스트파일이기 때문에 버전관리시스템을 이용하여 변경이력을 관리할 수 있습니다.
# 6. 지원하는 프로그램과 플랫폼이 다양합니다.
# ```
#
# ** Markdown 문법의 단점 **
#
# ```{admonition} 단점
# 1. 표준이 없습니다.
# 2. 표준이 없기 때문에 도구에 따라서 변환방식이나 생성물이 다릅니다.
# 3. 모든 HTML 마크업을 대신하지 못합니다.
# ```

# %% [markdown]
# ### 구글 코랩
#
# 구글 코랩(colab)은 콜라보레이토리(Google Colaboratory)를 줄여서 부르는 말입니다. 구글 코랩은 Python의 주피터 노트북을 구글 드라이브에 구현해 놓은 형태라고 볼 수 있고 다음과 같은 특징이 있습니다.
#
# * 별도의 구성 필요 없음
# * GPU, TPU 등의 자원을 이용할 수 있음
# * 간편하게 노트북 파일을 공유할 수 있음
# * 파일 입출력을 위해 구조를 이해해야 함
#
# 스마트 기기(테블릿, 아이패드, 스마트폰 등)에서 구글 드라이브 앱으로 코랩 파일을 열면 ”지원되지 않는 파일 형식“ 이라고 나오는데, 해당파일의 링크를 복사하여 그롬 브랑 저에서 열면 핸드폰이나 테블릿에서 열면 정상적으로 보실 수 있습니다. 구글 코랩은 주피터 노트북과 같이 텍스트 셀과 코드 셀로 이루여져 있으며 누구나 쉽게 편집할 수 있는 형태로 되어 있습니다. 크롬 브라우져로 구글에 로그인 한 후, 구글 코랩에 접속하기만 하면 누구나 브라우저에서 쉽게 Python을 작성하고 실행할 수 있습니다.
#
# 코랩을 사용하면 <strong>실행 코드</strong>와 <strong>서식 있는 텍스트</strong>를 <strong>이미지</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> 등과 함께 하나의 문서로 통합할 수 있습니다. 코랩 파일을 만들면 Google 드라이브 계정에 저장되고, 코랩 파일을 간편하게 공유하여 동료나 친구들이 댓글을 달거나 수정하도록 할 수 있습니다. 자세히 알아보려면 <a href="/notebooks/basic_features_overview.ipynb">Colab 개요</a>를 참고하기 바랍니다.

# %% [markdown]
# #### 코랩 환경 설정
#
# 코랩 사용시 다음의 환경 설정을 알아두면 도움이 될 것이다.
#
# ```{admonition} 코랩 환경 설정
# * [메뉴] - [도구] - [설정]
# * [메뉴] - [런타임] - [런타임 유형 변경]
# ```

# %% [markdown]
# ### 코랩에서 한글 사용하기
#
# 구글 코랩에서 matplotlib으로 챠트를 그리는 경우 한글이 나타나지 않을 수 있습니다. 이는 폰트가 없거나 폰트 경로를 설정하지 않아서 나타나는 현상으로 구글링하면 쉽게 그 해결책을 찾을 수 있습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X 축', labelpad=15)
plt.ylabel('Y 축', labelpad=20)
plt.show()

# %% [markdown]
# 구글 코랩에서 한글을 사용하기 위해서는 폰트를 설치해 줘야 하는데, 아래 코드를 실행 한 후 런타임 다시 시작을 해 줘야 제대로 적용이 될 것이다.

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ![image-20200613022022002.png](data:image/png;base64,...)

# %% [markdown]
# 그리고 나서 폰트 경로를 알려주면 한글 사용이 가능해 집니다.

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# 이제 한글이 제대로 나타나는 것을 확인할 수 있습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X 축', labelpad=15)
plt.ylabel('Y 축', labelpad=20)
plt.show()

# %% [markdown]
# #### 구글 드라이브 마운트 (mount google drive..)
#
# 구글 코랩에서 생성된 파일은 런타임이 끊어질 때 삭제됩니다. 만약 삭제되기를 원치 않는다면 구글 드라이브를 마운트 하여 사용하면 코드 실행 결과 생성된 파일을 자신의 구글 드라이브에 생성할 수 있습니다.
#
# 1. 아래 셀을 실행합니다.
# 2. 화면에 표시된 링크로 접속합니다.
# 3. 연결할 구글 드라이브 계정으로 로그인하고 허용을 누릅니다.
# 4. 드라이브 마운트 허용 코드를 복사합니다. (옆의 복사 버튼 누르면 간편)
# 5. Authorization Code 입력 부분에 붙여넣기한 후 엔터치면 연결됩니다.
# 6. 경로 설정을 합니다.  drive.mount('/content/drive/My Drive/dacon')

# %%
#from google.colab import drive
#drive.mount('/content/drive') #처음부터 경로를 이곳에 설정해 주면 더 편할 수 있습니다.

# %% [markdown]
# ### 스파이더(spyder)
#
# Spyder는 Anaconda 배포본에 포함되어 있는 IDE로, 에디터와 콘솔을 지원하기 때문에 위의 작업을 편하기 수행할 수 있습니다. 또한, 프로젝트, 디버깅, 헬프, 변수 보기(variable explorere) 등 다양한 편의기능을 제공합니다.
#
# Spyder는 대화형창(콘솔)으로 표준 Python 콘솔을 확장한 IPython 콘솔을 사용합니다. 편집기에서 편집하다가 스크립트를 전체 수행하거나 일부 영역을 선택한 후 그 부분만 수행할 수 있습니다.

# %% [markdown]
# ![03.png](data:image/png;base64,...)

# %% [markdown]
# 1. The Editor window. This is the place were you'll write your scripts and modify you programs.
#
# 2. This is the Object Inspector, where it'll be presented information about modules, procedures and functions that your are using in your script. We'll return to that later on.
#
# 3. This is the Console, where you can have acess to the Python Shell and the results of your script.

# %% [markdown]
# ### 파이참(Pycharm)
#
# Pycharm은 이름에서 알 수 있습니다.시피 파이썬에 아주 유용한 IDE 이고 아주 많은 편의성을 제공해 줍니다. Pychram은 프로페셔널(Professional)과 커뮤니티(Community) 2가지의 버전이 있는데, 커뮤니티 버전은 무료이고, 프로페셔설 버전은 유료입니다. 초보라면 커뮤니티 버전에 있는 기능 만으로도 충분하지만 프로페셔널 이전을 사용해 보고 싶다면 교육자 인증을 받으면 무료로 사용할 수 있습니다.
#
# Pycharm이 아주 좋은 기능들이 많이 있지만 프로그램이 다소 무거운 것이 단점이라면 단점이라고 할 수 있습니다.

# %% [markdown]
# ![Pycharm.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### VS code 사용
#
# VS code(Visual Studio Code)는 Microsoft에서 제공하는 가벼운 IDE입니다. VS Code는  설치 후 python extension 등 필요한 extension을 인스톨하여 그 기능을 확장하는 형태로 사용합니다. Python 코딩에도 매우 편리하며 주피터 노트북 사용도 매우 편리하게 해 줍니다.
#
# VS code에서는 필요한 extension을 설치를 추천하는데, 위치와 삭제는 간단하며, 다음의 쉬운 extension을 설치하면 됩니다.
#
# * Python : Microsoft 제공. Python 사용을 위해 필요
#
# * Jupyter : Jupyter 사용을 위해 필요
#
# * Material Icon Theme : 파일 아이콘을 멋지게 보여줌.
#
# VS code에서 주피터 노트북을 열어본 모습은 다음 그림과 같다.

# %% [markdown]
# ![vs_code_jupyter.png](data:image/png;base64,...)

# %% [markdown]
# ### 기타
#
# 아니콘다 이외에도 Catopy 등 다양한 툴들이 있는데 어떠한 툴을 이용할 것인지는 사용자의 선택사항이라고 할 수 있습니다.

# %% [markdown]
# ![Canopy_web.png](data:image/png;base64,...)

# %% [markdown]
# ## 감사합니다.
